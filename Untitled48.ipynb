# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\Administrator\Downloads\adult11.csv")

# %%
data.head(5)
# Out:
#    age  workclass  fnlwgt     education  education-num      marital-status  \
# 0   25    Private  226802          11th              7       Never-married
# 1   38    Private   89814       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  160323  Some-college             10  Married-civ-spouse
# 4   18          ?  103497  Some-college             10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country salary
# ...

# %% [markdown]
# we create a visualization demonstrating which columns has a strong relationship with age from range 0-1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = data.corr(numeric_only=True)
plt.figure(figsize=(10,6))
sns.heatmap(corr[['age']].sort_values(by='age', ascending=False), annot=True, cmap='coolwarm')
plt.title('Feature Correlation with Age')
plt.show()

# %%
x=data['age'].values.reshape(-1,1)
y=data['hours-per-week'].values.reshape(-1,1)

# %% [markdown]
# The blue line (Linear Regression) suggests a slight increase in hours worked as age increases — but overall, the relationship is weak and flat.
#
# The red curve (Polynomial Regression) shows a more realistic pattern:
#
# Younger workers (ages ~20–40) tend to work more hours per week, possibly due to higher energy, career-building motivation, or fewer family constraints.
#
# Middle-aged workers (~40–55) show a stable workload.
#
# Older workers (~60+) show a decline in hours, likely due to semi-retirement, reduced roles, or part-time work

# %%
linear_model = LinearRegression()
linear_model.fit(x, y)
y_pred_linear = linear_model.predict(x)

# Plot both
plt.figure(figsize=(8,6))
plt.scatter(x, y, color='lightgray', alpha=0.6, label='Actual Data')
plt.plot(x, y_pred_linear, color='blue', label='Linear Regression')
plt.plot(x_sorted, y_poly_sorted, color='red', label='Polynomial Regression (Degree 2)')
plt.title("Linear vs Polynomial Regression")
plt.xlabel("Age")
plt.ylabel("Hours per Week")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# R² (Polynomial) is higher, it means a nonlinear (curved) model fits the data better.

# %%
from sklearn.metrics import r2_score
y_pred_linear = linear_model.predict(x)
r2_linear = r2_score(y, y_pred_linear)


poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(x)
poly_model = LinearRegression()
poly_model.fit(X_poly, y)
y_pred_poly = poly_model.predict(X_poly)
r2_poly = r2_score(y, y_pred_poly)

print("Model Performance Comparison:")
print(f"R² Score (Linear Regression): {r2_linear:.4f}")
print(f"R² Score (Polynomial Regression, degree=2): {r2_poly:.4f}")
# Out:
# Model Performance Comparison:
# R² Score (Linear Regression): 0.0051
# R² Score (Polynomial Regression, degree=2): 0.1294
